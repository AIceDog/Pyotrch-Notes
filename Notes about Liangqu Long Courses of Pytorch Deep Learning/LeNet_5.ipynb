# %% [markdown]
# <a href="https://colab.research.google.com/github/AIceDog/Pyotrch-Notes/blob/master/Notes%20about%20Liangqu%20Long%20Courses%20of%20Pytorch%20Deep%20Learning/LeNet_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this picture, there are 5 layers(2 convolution layers and 3 full connection layers, subsampling isn't a layer)

# %% [markdown]
# ![lenet.png](data:image/png;base64,...)
