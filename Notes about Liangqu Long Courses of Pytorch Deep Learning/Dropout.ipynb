# %% [markdown]
# <a href="https://colab.research.google.com/github/AIceDog/Pyotrch-Notes/blob/master/Notes%20about%20Liangqu%20Long%20Courses%20of%20Pytorch%20Deep%20Learning/Dropout.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torch

# %%
import torch
from torch.nn.modules.dropout import Dropout

# %% [markdown]
# ![Dropout.png](data:image/png;base64,...)

# %%
net_dropped = torch.nn.Sequential(
    torch.nn.Linear(784, 200),   # layer 1
    torch.nn.Dropout(0.5),   # drop 50% of the neuron connection between layer 1 and layer 2
    torch.nn.ReLU(),
    torch.nn.Linear(200, 200),   # layer 2
    torch.nn.Dropout(0.5),   # drop 50% of the neuron connection between layer 2 and layer 3
    torch.nn.ReLU(),
    torch.nn.Linear(200, 10),   # layer 3
)

# %% [markdown]
# torch.nn.Dropout(0.7) indicates drop 70% of the neuron connection between layers
#
# tf.nn.dropout(0.7) indicates drop 30% of the neuron connection between layers

# %% [markdown]
# We must keep full connection and disable dropout when testing

# %%
for epoch in range(epochs):

  # train
  net_dropped.train()
  for batch_idx, (data, target) in enumerate(train_loader):
    ...
  net_dropped.eval()   # We must keep full connection and disable dropout when testing
  test_loss = 0
  correct = 0
  for data, target in test_loader:
    ...
