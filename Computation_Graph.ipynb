# %% [markdown]
# <a href="https://colab.research.google.com/github/AIceDog/Pyotrch-Notes/blob/master/Computation_Graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
import numpy as np
import torch
import torch.nn as nn

# %%
x = torch.tensor([0.5, 0.75], requires_grad=True)
y = torch.log(x[0] * x[1]) * torch.sin(x[1])
y.backward()
x.grad
# Out:
# tensor([1.3633, 0.1912])

# %% [markdown]
# ![augmented_computational_graph.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![1675878461216.png](data:image/png;base64,...)
